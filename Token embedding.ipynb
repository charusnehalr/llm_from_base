# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from gensim) (2.3.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from gensim) (1.16.0)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart_open>=1.8.1->gensim)
#   Downloading wrapt-2.0.1-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/24.4 MB 28.6 MB/s eta 0:00:01
#    --- ------------------------------------ 2.4/24.4 MB 5.9 MB/s eta 0:00:04
#    -------- ------------------------------- 5.2/24.4 MB 11.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.3/24.4 MB 8.5 MB/s eta 0:00:03
#    ------------ --------------------------- 7.3/24.4 MB 7.8 MB/s eta 0:00:03
#    -------------- ------------------------- 8.7/24.4 MB 7.3 MB/s eta 0:00:03
#    --------------- ------------------------ 9.4/24.4 MB 6.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 10.7/24.4 MB 6.7 MB/s eta 0:00:03
#    ------------------ --------------------- 11.5/24.4 MB 6.4 MB/s eta 0:00:03
#    ------------------- -------------------- 12.1/24.4 MB 6.2 MB/s eta 0:00:02
#    -------------------- ------------------- 12.6/24.4 MB 5.7 MB/s eta 0:00:03
#    --------------------- ------------------ 12.8/24.4 MB 5.5 MB/s eta 0:00:03
#    --------------------- ------------------ 13.4/24.4 MB 5.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 13.9/24.4 MB 5.0 MB/s eta 0:00:03
#    ------------------------ --------------- 14.7/24.4 MB 4.8 MB/s eta 0:00:03
#    ------------------------ --------------- 15.2/24.4 MB 4.7 MB/s eta 0:00:02
#    -------------------------- ------------- 16.0/24.4 MB 4.7 MB/s eta 0:00:02
#    --------------------------- ------------ 16.8/24.4 MB 4.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.8/24.4 MB 4.6 MB/s eta 0:00:02
#    ------------------------------ --------- 18.6/24.4 MB 4.6 MB/s eta 0:00:02
#    -------------------------------- ------- 19.7/24.4 MB 4.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.0/24.4 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 22.0/24.4 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.4 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 4.8 MB/s eta 0:00:00
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Downloading wrapt-2.0.1-cp313-cp313-win_amd64.whl (60 kB)
# Installing collected packages: wrapt, smart_open, gensim
#
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    ---------------------------------------- 3/3 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.5.0 wrapt-2.0.1

# %%
import gensim.downloader as api
model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
word_vectors = model

print(word_vectors['computer'])
# Out:
# [ 1.07421875e-01 -2.01171875e-01  1.23046875e-01  2.11914062e-01
#  -9.13085938e-02  2.16796875e-01 -1.31835938e-01  8.30078125e-02
#   2.02148438e-01  4.78515625e-02  3.66210938e-02 -2.45361328e-02
#   2.39257812e-02 -1.60156250e-01 -2.61230469e-02  9.71679688e-02
#  -6.34765625e-02  1.84570312e-01  1.70898438e-01 -1.63085938e-01
#  -1.09375000e-01  1.49414062e-01 -4.65393066e-04  9.61914062e-02
#   1.68945312e-01  2.60925293e-03  8.93554688e-02  6.49414062e-02
#   3.56445312e-02 -6.93359375e-02 -1.46484375e-01 -1.21093750e-01
#  -2.27539062e-01  2.45361328e-02 -1.24511719e-01 -3.18359375e-01
#  -2.20703125e-01  1.30859375e-01  3.66210938e-02 -3.63769531e-02
#  -1.13281250e-01  1.95312500e-01  9.76562500e-02  1.26953125e-01
#   6.59179688e-02  6.93359375e-02  1.02539062e-02  1.75781250e-01
#  -1.68945312e-01  1.21307373e-03 -2.98828125e-01 -1.15234375e-01
#   5.66406250e-02 -1.77734375e-01 -2.08984375e-01  1.76757812e-01
#   2.38037109e-02 -2.57812500e-01 -4.46777344e-02  1.88476562e-01
#   5.51757812e-02  5.02929688e-02 -1.06933594e-01  1.89453125e-01
print(word_vectors.similarity('king', 'queen'))
print(word_vectors.similarity('uncle', 'aunt'))
print(word_vectors.similarity('boy', 'girl'))
print(word_vectors.similarity('nephew', 'niece'))
print(word_vectors.similarity('paper', 'water'))
# Out:
# 0.76640123
# 0.6510957
# 0.76434743
# 0.8543272
# 0.7594367
# 0.11408083

# %%
print(word_vectors.most_similar("tower", topn=5))
# Out:
# [('towers', 0.8531749248504639), ('skyscraper', 0.6417425870895386), ('Tower', 0.639177143573761), ('spire', 0.5946877598762512), ('responded_Understood_Atlasjet', 0.5931612849235535)]

# %%
import numpy as np 

word1='man'
word2='woman'

word3='semiconductor'
word4='earthworm'

word5='nephew'
word6='niece'

# calculate the vector difference
vector_difference1 = model[word1] - model[word2]
vector_difference2 = model[word3] - model[word4]
vector_difference3 = model[word5] - model[word6]

#calculate the magnitude of the vector difference
magnitude_of_difference1 = np.linalg.norm(vector_difference1)
magnitude_of_difference2 = np.linalg.norm(vector_difference2)
magnitude_of_difference3 = np.linalg.norm(vector_difference3)

print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word1,word2,magnitude_of_difference1))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word3,word4,magnitude_of_difference2))
print("The magnitude of the difference between '{}' and '{}' is {:.2f}".format(word5,word6,magnitude_of_difference3))
# Out:
# The magnitude of the difference between 'man' and 'woman' is 1.73
# The magnitude of the difference between 'semiconductor' and 'earthworm' is 5.67
# The magnitude of the difference between 'nephew' and 'niece' is 1.96

# %% [markdown]
# ### Creating token embeddings

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (2.9.0+cpu)
# Requirement already satisfied: filelock in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rajarathinam\anaconda3\envs\myenv\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
import torch
input_ids = torch.tensor([2,3,5,1])

# let's create a small vocabulary of 6 words (inplace of 50k words in BPE)
# the embedding is of size 3

# %%
vocab_size = 6
output_dim = 3

torch.manual_seed(123)
embedding_layer = torch.nn.Embedding(vocab_size, output_dim)

# %%
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 0.3374, -0.1778, -0.1690],
#         [ 0.9178,  1.5810,  1.3010],
#         [ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-1.1589,  0.3255, -0.6315],
#         [-2.8400, -0.7849, -1.4096]], requires_grad=True)

# %%
print(embedding_layer(torch.tensor([3])))
# Out:
# tensor([[-0.4015,  0.9666, -1.1481]], grad_fn=<EmbeddingBackward0>)

# %%
print(embedding_layer(input_ids))
# Out:
# tensor([[ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-2.8400, -0.7849, -1.4096],
#         [ 0.9178,  1.5810,  1.3010]], grad_fn=<EmbeddingBackward0>)
